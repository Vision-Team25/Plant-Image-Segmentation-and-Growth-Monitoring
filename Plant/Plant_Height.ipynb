# %%
import cv2  # Import OpenCV library
import numpy as np  # Import NumPy for array operations

# Hue (H) range: 0-180 in OpenCV (Red: 0-60, Green: 60-120, Blue: 120-180)
# Saturation (S) & Value (V) range: 0-255

# Function placeholder 
def nothing(x):
    pass  

# Create a window to display results
cv2.namedWindow('result')

# Initialize trackbar values (default H=100, S=100, V=100)
h, s, v = 100, 100, 100

# Create trackbars to adjust HSV values dynamically
cv2.createTrackbar('h', 'result', 0, 179, nothing)  # Hue trackbar (0-179)
cv2.createTrackbar('s', 'result', 0, 255, nothing)  # Saturation trackbar (0-255)
cv2.createTrackbar('v', 'result', 0, 255, nothing)  # Value trackbar (0-255)

# Infinite loop for real-time HSV adjustment
while True:
    # Read the image 
    frame = cv2.imread('plant.jpg')  # Load plant image
    
    # Resize the image for consistent display
    frame = cv2.resize(frame, (650, 350))

    # Convert the BGR image to HSV color space
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    # Read trackbar values for dynamic HSV adjustment
    h = cv2.getTrackbarPos('h', 'result')  # Get updated Hue value
    s = cv2.getTrackbarPos('s', 'result')  # Get updated Saturation value
    v = cv2.getTrackbarPos('v', 'result')  # Get updated Value (Brightness)

    # Define the lower and upper HSV color range for masking
    lower_green = np.array((h, s, v))  # Lower bound for green shades
    upper_green = np.array((55, 255, 255))  # Upper bound for green shades

    # Create a binary mask where the selected color range is white, and others are black
    mask = cv2.inRange(hsv, lower_color, upper_color)

    # Apply the mask to the original image using bitwise AND operation
    result = cv2.bitwise_and(frame, frame, mask=mask)

    # Display the result (Masked image)
    cv2.imshow('result', result)

    # Exit loop when 'Esc' key (27) is pressed
    k = cv2.waitKey(5) & 0xFF
    if k == 27:  
        break  

# Close all OpenCV windows
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16636\352806445.py in <module>
#      32
#      33     # Read trackbar values for dynamic HSV adjustment
# ---> 34     h = cv2.getTrackbarPos('h', 'result')  # Get updated Hue value
#      35     s = cv2.getTrackbarPos('s', 'result')  # Get updated Saturation value
#      36     v = cv2.getTrackbarPos('v', 'result')  # Get updated Value (Brightness)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2561: error: (-27:Null pointer) NULL window: 'result' in function 'cvGetTrackbarPos'

# %%
import cv2  # Import OpenCV for image processing
import numpy as np  # Import NumPy for numerical operations

# Load the plant image
frame = cv2.imread('plant.jpg')

# Get image dimensions (height and width)
height, width = frame.shape[0:2]

# Resize the image for better processing and display
frame = cv2.resize(frame, (750, 550))

# Convert the image from BGR to HSV color space
hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

# Define the lower and upper HSV bounds for detecting green regions (plant)
lower_green = np.array([20, 45, 65])  # Lower bound for green shades
upper_green = np.array([55, 255, 255])  # Upper bound for green shades

# Create a binary mask where the detected green areas are white (255) and the rest are black (0)
mask = cv2.inRange(hsv, lower_green, upper_green)

# Apply the mask to the original image to keep only the detected green regions
res = cv2.bitwise_and(frame, frame, mask=mask)

# Find contours in the binary mask
contours, hierarchy = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# Print the number of contours (detected plant regions)
print('Number of contours:', len(contours))

# Loop through each detected contour
for cnt in contours:
    # Calculate the area of the contour
    area = cv2.contourArea(cnt)
    print("Contour Area:", area)

    # Only process contours with significant area to avoid noise
    if area > 2000:  
        # Draw the contour in yellow (0,255,255) with thickness 1
        cv2.drawContours(frame, [cnt], -1, (0, 255, 255), 1)
        
        # Get bounding box coordinates (x, y, width, height)
        x, y, w, h = cv2.boundingRect(cnt)
        
        # Draw a green bounding rectangle around the detected plant
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
        
        # Mark the top and bottom of the plant with red circles
        cv2.circle(frame, (int(x + w / 2), y), 5, (0, 0, 255), -1)  # Top center
        cv2.circle(frame, (int(x + w / 2), y + h), 5, (0, 0, 255), -1)  # Bottom center

        # Display the plant height on the image
        cv2.putText(frame, "Height: " + str(h), (x + w, y + h), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

# Display the original image with detected contours
cv2.imshow('frame', frame)

# Display the binary mask (only detected plant regions)
cv2.imshow('mask', mask)

# Wait indefinitely for a key press
k = cv2.waitKey(0)

# Close all OpenCV windows when any key is pressed
cv2.destroyAllWindows()
# Out:
# Number of contours: 349
# Contour Area: 80.0
# Contour Area: 2.0
# Contour Area: 0.0
# Contour Area: 51.5
# Contour Area: 0.5
# Contour Area: 0.5
# Contour Area: 11.5
# Contour Area: 10.0
# Contour Area: 1017.5
# Contour Area: 2.0
# Contour Area: 4.0
# Contour Area: 10.5
# Contour Area: 23.5
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 16.5
# Contour Area: 4.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 18.0
# Contour Area: 2.0
# Contour Area: 1.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 22.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 2.5
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.5
# Contour Area: 27.5
# Contour Area: 0.0
# Contour Area: 25.0
# Contour Area: 2.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 31.5
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 3.5
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 2.5
# Contour Area: 4.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 7.5
# Contour Area: 15.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 3.5
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 3.5
# Contour Area: 11.5
# Contour Area: 0.0
# Contour Area: 13.5
# Contour Area: 14.5
# Contour Area: 0.0
# Contour Area: 16.5
# Contour Area: 2.0
# Contour Area: 0.0
# Contour Area: 2.5
# Contour Area: 0.0
# Contour Area: 1.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.5
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.5
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 19.5
# Contour Area: 1.5
# Contour Area: 4.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 1.0
# Contour Area: 0.0
# Contour Area: 0.5
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 11.0
# Contour Area: 35.5
# Contour Area: 4.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 0.0
# Contour Area: 40.5
# Contour Area: 0.0
# Contour Area: 0.5
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 1.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 18.0
# Contour Area: 2.0
# Contour Area: 1.0
# Contour Area: 0.0
# Contour Area: 51.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 1.0
# Contour Area: 0.0
# Contour Area: 1.0
# Contour Area: 1.0
# Contour Area: 42.5
# Contour Area: 4.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 114.0
# Contour Area: 4.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 11.5
# Contour Area: 15.0
# Contour Area: 2.0
# Contour Area: 4.0
# Contour Area: 5.5
# Contour Area: 0.5
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 77.0
# Contour Area: 9.0
# Contour Area: 5.5
# Contour Area: 5.5
# Contour Area: 4.0
# Contour Area: 2.0
# Contour Area: 1.0
# Contour Area: 1.0
# Contour Area: 0.5
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 13.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 30.0
# Contour Area: 2.0
# Contour Area: 0.0
# Contour Area: 0.5
# Contour Area: 0.0
# Contour Area: 1.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.5
# Contour Area: 0.0
# Contour Area: 3.0
# Contour Area: 3.5
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 1.0
# Contour Area: 1.0
# Contour Area: 327.5
# Contour Area: 2.0
# Contour Area: 4.0
# Contour Area: 12.0
# Contour Area: 2.0
# Contour Area: 19.0
# Contour Area: 2.0
# Contour Area: 23.5
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 5.5
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 4.0
# Contour Area: 2.0
# Contour Area: 29.0
# Contour Area: 2.0
# Contour Area: 5.5
# Contour Area: 2.0
# Contour Area: 0.0
# Contour Area: 0.5
# Contour Area: 0.0
# Contour Area: 73.5
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 0.0
# Contour Area: 0.5
# Contour Area: 7.5
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.5
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 4.0
# Contour Area: 61.0
# Contour Area: 4.0
# Contour Area: 2.0
# Contour Area: 36.5
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.5
# Contour Area: 18.5
# Contour Area: 4.0
# Contour Area: 24.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 135.5
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 11.0
# Contour Area: 0.5
# Contour Area: 2.0
# Contour Area: 1.0
# Contour Area: 2.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.5
# Contour Area: 25.5
# Contour Area: 1.5
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 3.0
# Contour Area: 1.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 0.0
# Contour Area: 44.5
# Contour Area: 2.0
# Contour Area: 15.0
# Contour Area: 2.0
# Contour Area: 0.0
# Contour Area: 10.5
# Contour Area: 27.5
# Contour Area: 2.0
# Contour Area: 1.5
# Contour Area: 19.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 7.0
# Contour Area: 18.5
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 1.0
# Contour Area: 0.0
# Contour Area: 1.0
# Contour Area: 0.0
# Contour Area: 1.5
# Contour Area: 0.0
# Contour Area: 0.5
# Contour Area: 4330.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 8.5
# Contour Area: 6.0
# Contour Area: 16.0
# Contour Area: 14.0
# Contour Area: 2.0
# Contour Area: 26.0
# Contour Area: 2.0
# Contour Area: 5.5
# Contour Area: 2.0
# Contour Area: 7.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 16.5
# Contour Area: 30.0
# Contour Area: 9.0
# Contour Area: 2.0
# Contour Area: 2.0
# Contour Area: 50.5
# Contour Area: 2.0
# Contour Area: 8.5
# Contour Area: 2.0
# Contour Area: 133.5
